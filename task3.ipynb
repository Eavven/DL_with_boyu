# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 范数
# ![image.png](attachment:image.png)

# %% [markdown]
#  0范数，向量中非零元素的个数。
# L1范数（L1 norm）是指向量中各个元素绝对值之和，美称叫“稀疏规则算子”（Lasso regularization）。
# ![image.png](attachment:image.png)

# %% [markdown]
# L1范数会趋向产生少量的特征，其他特征的权值都是0；L2会选择更多的特征，这些特征的权值都会接近于0。
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 权重衰减等价于L2范数正则化（regularization）。正则化通过为模型损失函数添加惩罚项使学出的模型参数值较小，是应对过拟合的常用手段。

# %% [markdown]
# # early stopping

# %% [markdown]
# ![image.png](attachment:image.png)
